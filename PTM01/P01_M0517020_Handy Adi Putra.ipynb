# %%
from PIL import Image

# %%
img = Image.open('4.1.08.tiff')
img
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256 at 0x15F464BD128>

# %%
img.getpixel((100,100))
# Out:
# (52, 15, 46)

# %%
img_gray = img.convert('L')
img_gray
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x15F466A3278>

# %%
img_gray.getpixel((100,100))
# Out:
# 29

# %%
img_gray.save('img_gray.tiff')
